# %% [markdown]
# # Exámen Intento 3
#
# ## Fundamentos de Data Science - Analizando la Rotación de Clientes en Telecomunicaciones

# %% [markdown]
# ## Instrucciones

# %% [markdown]
# ### Requisitos:
#
# Tu tarea es limpiar y explorar un dataset para los ejecutivos de una empresa de telecomunicaciones que describe tendencias en la rotación de sus clientes.
#
# ### Instrucciones:
#
# 1. Limpieza de datos con Python:
#    * Identificar y solucionar cualquier valor duplicado.
#    * Asegurarse de que todas las columnas coincidan con los tipos de datos indicados en el diccionario de datos.
#    * Identificar y solucionar cualquier inconsistencia en los valores categóricos (ejemplo: cat, Cat, cats).
#    * Identificar y solucionar cualquier valor faltante en el dataset. Rellenar los valores faltantes con un marcador adecuado para el tipo de dato.
#    * Identificar y solucionar cualquier punto de dato inapropiado o inusual (ejemplo: la edad no puede ser 325).
# 2.  Exploración de datos con Python:
#     * Crear dos tipos diferentes de visualizaciones exploratorias univariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.
#     * Crear dos tipos diferentes de visualizaciones exploratorias multivariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.

# %% [markdown]
# ## Sobre los campos del dataset

# %% [markdown]
# About this file
#
#
# 1. **customerID**: Customer ID
# 2. **gender**: Whether the customer is a male or a female
# 3. **SeniorCitizen**: Whether the customer is a senior citizen or not (1, 0)
# 4. **Partner**: Whether the customer has a partner or not (Yes, No)
# 5. **Dependents**: Whether the customer has dependents or not (Yes, No)
# 6. **tenure**: Number of months the customer has stayed with the company
# 7. **PhoneService**: Whether the customer has a phone service or not (Yes, No)
# 8. **MultipleLines**: Whether the customer has multiple lines or not (Yes, No, No phone service)
# 9. **InternetService** Customer’s internet service provider (DSL, Fiber optic, No)
# 10. **OnlineSecurity**: Whether the customer has online security or not (Yes, No, No internet service)
# 11. **OnlineBackup**: Whether the customer has online backup or not (Yes, No, No internet service)
# 12. **DeviceProtection**: Whether the customer has device protection or not (Yes, No, No internet service)
# 13. **TechSupport**: Whether the customer has tech support or not (Yes, No, No internet service)
# 14. **StreamingTV**: Whether the customer has streaming TV or not (Yes, No, No internet service)
# 15. **StreamingMovies** Whether the customer has streaming movies or not (Yes, No, No internet service)
# 16. **Contract**: The contract term of the customer (Month-to-month, One year, Two year)
# 17. **PaperlessBilling**: Whether the customer has paperless billing or not (Yes, No)
# 18. **PaymentMethod**: The customer’s payment method (Electronic check, Mailed check, Bank transfer (automatic), Credit card (automatic))
# 19. **MonthlyCharges**: The amount charged to the customer monthly
# 20. **TotalCharges**: The total amount charged to the customer
# 21. **Churn** Whether the customer churned or not (Yes or No)
#
#
#
# *Traducción de los campos del dataset*
#
#
# 1. **ID del cliente**: ID del cliente
# 2. **género**: Si el cliente es hombre o mujer.
# 3. **SeniorCitizen**: Si el cliente es de la tercera edad o no (1, 0)
# 4. **Pareja**: Si el cliente tiene pareja o no (Sí, No).
# 5. **Dependientes**: Si el cliente tiene o no personas a su cargo (Sí, No).
# 6. **Antigüedad**: Número de meses que el cliente ha permanecido en la empresa.
# 7. **ServicioTelefónico**: Si el cliente dispone o no de servicio telefónico (Sí, No).
# 8. **LíneasMúltiples**: Si el cliente tiene varias líneas o no (Sí, No, Sin servicio telefónico).
# 9. **InternetService** Proveedor de servicios de Internet del cliente (DSL, Fibra óptica, No).
# 10. **Seguridad en línea**: Si el cliente dispone de seguridad en línea o no (Sí, No, Sin servicio de Internet).
# 11. **Copia de seguridad en línea**: Si el cliente tiene copia de seguridad en línea o no (Sí, No, Sin servicio de internet).
# 12. **ProtecciónDispositivos**: Si el cliente dispone de protección de dispositivos o no (Sí, No, Sin servicio de internet).
# 13. **SoporteTécnico**: Si el cliente tiene soporte técnico o no (Sí, No, Sin servicio de internet).
# 14. **StreamingTV**: Si el cliente dispone o no de televisión en streaming (Sí, No, Sin servicio de internet).
# 15. **StreamingMovies**: Si el cliente tiene streaming de películas o no (Sí, No, Sin servicio de internet)
# 16. **Contrato**: La duración del contrato del cliente (Mes a mes, Un año, Dos años)
# 17. **Facturación sin papel**: Si el cliente tiene o no facturación sin papel (Sí, No).
# 18. **Método de pago**: El método de pago del cliente (Cheque electrónico, Cheque enviado por correo, Transferencia bancaria (automática), Tarjeta de crédito (automática)).
# 19. **CargosMensuales**: El importe que se cobra mensualmente al cliente
# 20. **CargosTotales**: El importe total cobrado al cliente
# 21. **churn** :Si el cliente se ha dado de baja o no (Sí o No)
#
# ****

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ### 1. Limpieza de datos con Python:
#    * Identificar y solucionar cualquier valor duplicado.
#    * Asegurarse de que todas las columnas coincidan con los tipos de datos indicados en el diccionario de datos.
#    * Identificar y solucionar cualquier inconsistencia en los valores categóricos (ejemplo: cat, Cat, cats).
#    * Identificar y solucionar cualquier valor faltante en el dataset. Rellenar los valores faltantes con un marcador adecuado para el tipo de dato.
#    * Identificar y solucionar cualquier punto de dato inapropiado o inusual (ejemplo: la edad no puede ser 325).

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
import json
import re
import plotly.express as px
from IPython.display import display #Para Impiimir en formato TABLA

# %%
# Cargar datos desde un archivo CSV
path = r'C:\Users\GIGABYTE\Documents\examen_data_fundamentals\examen_intento_3\data\telco_customer_churn.csv'
df = pd.read_csv(filepath_or_buffer=path, sep= ',', header=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #### **Identificar y solucionar cualquier valor duplicado.**

# %%
# Identificar duplicados
duplicados = df.duplicated()
# Contar el número de duplicados
num_duplicados = duplicados.sum()
print(f"Número de registros duplicados: {num_duplicados}")
df.head()
# Out:
# Número de registros duplicados: 0
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #### **Asegurarse de que todas las columnas coincidan con los tipos de datos indicados en el diccionario de datos.**

# %%
# Definir el diccionario de tipos de datos
# Estandarizar nombres de columnas
df.columns = df.columns.str.lower().str.replace(' ', '_')
print(df.columns)
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
dataset_info = {
    "customerid": "string",
    "gender": "string",
    "seniorcitizen": "boolean",  # Cambiado a booleano
    "partner": "string",
    "dependents": "string",
    "tenure": "int64",
    "phoneservice": "string",
    "multiplelines": "string",
    "internetservice": "string",
    "onlinesecurity": "string",
    "onlinebackup": "string",
    "deviceprotection": "string",
    "techsupport": "string",
    "streamingtv": "string",
    "streamingmovies": "string",
    "contract": "string",
    "paperlessbilling": "string",
    "paymentmethod": "string",
    "monthlycharges": "float64",
    "totalcharges": "float64",  # Cambiado de string a float64
    "churn": "string"
}

# Función para mapear tipos personalizados a tipos de pandas
def map_tipo(tipo_personalizado):
    mapping = {
        'string': 'string',
        'float64': 'float64',
        'int64': 'int64',  # Añadido para el tipo int64
        'boolean': 'boolean'  # Añadido para el tipo boolean
    }
    return mapping.get(tipo_personalizado, 'object')  # 'object' como valor por defecto

# Crear un nuevo diccionario mapeado para pandas
dataset_info_mapeado = {col: map_tipo(tipo) for col, tipo in dataset_info.items()}

print("Diccionario Mapeado para pandas:")
print(dataset_info_mapeado)
# Out:
# Diccionario Mapeado para pandas:
# {'customerid': 'string', 'gender': 'string', 'seniorcitizen': 'boolean', 'partner': 'string', 'dependents': 'string', 'tenure': 'int64', 'phoneservice': 'string', 'multiplelines': 'string', 'internetservice': 'string', 'onlinesecurity': 'string', 'onlinebackup': 'string', 'deviceprotection': 'string', 'techsupport': 'string', 'streamingtv': 'string', 'streamingmovies': 'string', 'contract': 'string', 'paperlessbilling': 'string', 'paymentmethod': 'string', 'monthlycharges': 'float64', 'totalcharges': 'float64', 'churn': 'string'}

# %%
def validar_tipos(df, diccionario):
    """
    Valida que cada columna en df tenga el tipo de dato especificado en diccionario.
    
    Parámetros:
    - df: DataFrame de pandas.
    - diccionario: Diccionario con columnas como llaves y tipos de datos como valores.
    
    Retorna:
    - mismatches: Lista de tuplas con (columna, tipo_actual, tipo_esperado) para discrepancias.
    """
    mismatches = []
    for columna, tipo_esperado in diccionario.items():
        if columna in df.columns:
            tipo_actual = str(df[columna].dtype)
            # Algunos dtypes pueden ser equivalentes pero diferentes en nombre
            # Por ejemplo, 'string' en pandas puede ser 'string[python]'
            # Comparar solo las partes relevantes
            if tipo_esperado.startswith('datetime') and tipo_actual.startswith('datetime'):
                continue  # Considerar igual si ambos son datetime
            elif tipo_actual != tipo_esperado:
                mismatches.append((columna, tipo_actual, tipo_esperado))
        else:
            mismatches.append((columna, 'No existe en el DataFrame', tipo_esperado))
    return mismatches

# Ejecutar la validación
mismatches = validar_tipos(df, dataset_info_mapeado)

# Mostrar resultados
if not mismatches:
    print("Todos los tipos de datos son correctos.")
else:
    print("Discrepancias encontradas en los tipos de datos:")
    for columna, actual, esperado in mismatches:
        print(f"- Columna '{columna}': Tipo actual -> {actual}, Tipo esperado -> {esperado}")
# Out:
# Discrepancias encontradas en los tipos de datos:
# - Columna 'customerid': Tipo actual -> object, Tipo esperado -> string
# - Columna 'gender': Tipo actual -> object, Tipo esperado -> string
# - Columna 'seniorcitizen': Tipo actual -> int64, Tipo esperado -> boolean
# - Columna 'partner': Tipo actual -> object, Tipo esperado -> string
# - Columna 'dependents': Tipo actual -> object, Tipo esperado -> string
# - Columna 'phoneservice': Tipo actual -> object, Tipo esperado -> string
# - Columna 'multiplelines': Tipo actual -> object, Tipo esperado -> string
# - Columna 'internetservice': Tipo actual -> object, Tipo esperado -> string
# - Columna 'onlinesecurity': Tipo actual -> object, Tipo esperado -> string
# - Columna 'onlinebackup': Tipo actual -> object, Tipo esperado -> string
# - Columna 'deviceprotection': Tipo actual -> object, Tipo esperado -> string
# - Columna 'techsupport': Tipo actual -> object, Tipo esperado -> string
# ...

# %%
def validar_tipos(df, diccionario):
    """
    Valida que cada columna en df tenga el tipo de dato especificado en diccionario.
    
    Parámetros:
    - df: DataFrame de pandas.
    - diccionario: Diccionario con columnas como llaves y tipos de datos como valores.
    
    Retorna:
    - mismatches: Lista de tuplas con (columna, tipo_actual, tipo_esperado) para discrepancias.
    """
    mismatches = []
    for columna, tipo_esperado in diccionario.items():
        if columna in df.columns:
            tipo_actual = str(df[columna].dtype)
            # Verificación de tipos equivalentes
            if tipo_esperado.startswith('datetime') and tipo_actual.startswith('datetime'):
                continue  # Considerar igual si ambos son datetime
            elif tipo_esperado == 'boolean' and tipo_actual == 'bool':
                continue  # Considerar igual si ambos son booleanos
            elif tipo_actual != tipo_esperado:
                mismatches.append((columna, tipo_actual, tipo_esperado))
        else:
            mismatches.append((columna, 'No existe en el DataFrame', tipo_esperado))
    return mismatches

# Ejecutar la validación
mismatches = validar_tipos(df, dataset_info_mapeado)

# Mostrar resultados
if not mismatches:
    print("Todos los tipos de datos son correctos.")
else:
    print("Discrepancias encontradas en los tipos de datos:")
    for columna, actual, esperado in mismatches:
        print(f"- Columna '{columna}': Tipo actual -> {actual}, Tipo esperado -> {esperado}")
# Out:
# Discrepancias encontradas en los tipos de datos:
# - Columna 'customerid': Tipo actual -> object, Tipo esperado -> string
# - Columna 'gender': Tipo actual -> object, Tipo esperado -> string
# - Columna 'seniorcitizen': Tipo actual -> int64, Tipo esperado -> boolean
# - Columna 'partner': Tipo actual -> object, Tipo esperado -> string
# - Columna 'dependents': Tipo actual -> object, Tipo esperado -> string
# - Columna 'phoneservice': Tipo actual -> object, Tipo esperado -> string
# - Columna 'multiplelines': Tipo actual -> object, Tipo esperado -> string
# - Columna 'internetservice': Tipo actual -> object, Tipo esperado -> string
# - Columna 'onlinesecurity': Tipo actual -> object, Tipo esperado -> string
# - Columna 'onlinebackup': Tipo actual -> object, Tipo esperado -> string
# - Columna 'deviceprotection': Tipo actual -> object, Tipo esperado -> string
# - Columna 'techsupport': Tipo actual -> object, Tipo esperado -> string
# ...

# %%
def corregir_tipos(df, diccionario):
    """
    Corrige los tipos de datos de las columnas en df según lo especificado en diccionario.
    
    Parámetros:
    - df: DataFrame de pandas.
    - diccionario: Diccionario con columnas como llaves y tipos de datos como valores.
    
    Retorna:
    - df: DataFrame con tipos de datos corregidos.
    """
    for columna, tipo in diccionario.items():
        if columna in df.columns:
            try:
                if tipo == 'datetime64[ns]':
                    df[columna] = pd.to_datetime(df[columna], errors='coerce')
                else:
                    df[columna] = df[columna].astype(tipo)
            except Exception as e:
                print(f"Error al convertir la columna '{columna}' a '{tipo}': {e}")
    return df

# Corregir los tipos de datos
df = corregir_tipos(df, dataset_info_mapeado)

# Volver a validar
mismatches_post = validar_tipos(df, dataset_info_mapeado)

# Mostrar resultados después de la corrección
if not mismatches_post:
    print("Todos los tipos de datos han sido corregidos correctamente.")
else:
    print("Aún existen discrepancias después de la corrección:")
    for columna, actual, esperado in mismatches_post:
        print(f"- Columna '{columna}': Tipo actual -> {actual}, Tipo esperado -> {esperado}")
# Out:
# Error al convertir la columna 'totalcharges' a 'float64': could not convert string to float: ' '
# Aún existen discrepancias después de la corrección:
# - Columna 'totalcharges': Tipo actual -> object, Tipo esperado -> float64

# %%
def corregir_tipos(df, diccionario):
    """
    Corrige los tipos de datos de las columnas en df según lo especificado en diccionario.
    
    Parámetros:
    - df: DataFrame de pandas.
    - diccionario: Diccionario con columnas como llaves y tipos de datos como valores.
    
    Retorna:
    - df: DataFrame con tipos de datos corregidos.
    """
    for columna, tipo in diccionario.items():
        if columna in df.columns:
            try:
                # Manejar columnas que deben ser float pero tienen valores no convertibles (espacios en blanco, etc.)
                if tipo == 'float64':
                    df[columna] = pd.to_numeric(df[columna], errors='coerce')
                elif tipo == 'datetime64[ns]':
                    df[columna] = pd.to_datetime(df[columna], errors='coerce')
                elif tipo == 'boolean':
                    df[columna] = df[columna].astype('boolean')
                else:
                    df[columna] = df[columna].astype(tipo)
            except Exception as e:
                print(f"Error al convertir la columna '{columna}' a '{tipo}': {e}")
    return df

# Corregir los tipos de datos
df = corregir_tipos(df, dataset_info_mapeado)

# Volver a validar
mismatches_post = validar_tipos(df, dataset_info_mapeado)

# Mostrar resultados después de la corrección
if not mismatches_post:
    print("Todos los tipos de datos han sido corregidos correctamente.")
else:
    print("Aún existen discrepancias después de la corrección:")
    for columna, actual, esperado in mismatches_post:
        print(f"- Columna '{columna}': Tipo actual -> {actual}, Tipo esperado -> {esperado}")
# Out:
# Todos los tipos de datos han sido corregidos correctamente.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   string
#  1   gender            7043 non-null   string
#  2   seniorcitizen     7043 non-null   boolean
#  3   partner           7043 non-null   string
#  4   dependents        7043 non-null   string
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   string
#  7   multiplelines     7043 non-null   string
#  8   internetservice   7043 non-null   string
#  9   onlinesecurity    7043 non-null   string
#  10  onlinebackup      7043 non-null   string
#  11  deviceprotection  7043 non-null   string
#  12  techsupport       7043 non-null   string
#  13  streamingtv       7043 non-null   string
#  14  streamingmovies   7043 non-null   string
#  15  contract          7043 non-null   string
# ...

# %% [markdown]
# #### **Identificar y solucionar cualquier inconsistencia en los valores categóricos (ejemplo: cat, Cat, cats).**

# %%
# Lista de columnas categóricas a revisar
categorical_cols = [
    "gender",
    "partner",
    "dependents",
    "phoneservice",
    "multiplelines",
    "internetservice",
    "onlinesecurity",
    "onlinebackup",
    "deviceprotection",
    "techsupport",
    "streamingtv",
    "streamingmovies",
    "contract",
    "paperlessbilling",
    "paymentmethod"
]
# Diccionario para almacenar los valores únicos
valores_unicos = {}
for col in categorical_cols:
    unique_vals = df[col].dropna().unique().tolist()  # Eliminar NaN y convertir a lista
    valores_unicos[col] = unique_vals
    print(f"\nValores únicos en la columna '{col}':")
    print(unique_vals)

# Ruta donde se guardará el archivo JSON
ruta_json = r'C:\Users\GIGABYTE\Documents\examen_data_fundamentals\examen_intento_3\json\valores_unicos_iniciales.json'
# Guardar el diccionario en un archivo JSON
with open(ruta_json, 'w', encoding='utf-8') as f:
    json.dump(valores_unicos, f, ensure_ascii=False, indent=4)
    print(f"\nValores únicos guardados en '{ruta_json}'")
# Out:
# Valores únicos en la columna 'gender':
# ['Female', 'Male']
#
# Valores únicos en la columna 'partner':
# ['Yes', 'No']
#
# Valores únicos en la columna 'dependents':
# ['No', 'Yes']
#
# Valores únicos en la columna 'phoneservice':
# ['No', 'Yes']
#
# Valores únicos en la columna 'multiplelines':
# ['No phone service', 'No', 'Yes']
#
# Valores únicos en la columna 'internetservice':
# ['DSL', 'Fiber optic', 'No']
#
# Valores únicos en la columna 'onlinesecurity':
# ['No', 'Yes', 'No internet service']
#
# Valores únicos en la columna 'onlinebackup':
# ['Yes', 'No', 'No internet service']
#
# Valores únicos en la columna 'deviceprotection':
# ['No', 'Yes', 'No internet service']
#
# Valores únicos en la columna 'techsupport':
# ['No', 'Yes', 'No internet service']
#
# Valores únicos en la columna 'streamingtv':
# ['No', 'Yes', 'No internet service']
#
# Valores únicos en la columna 'streamingmovies':
# ['No', 'Yes', 'No internet service']
#
# Valores únicos en la columna 'contract':
# ...

# %%
def limpiar_cadena(cadena):
    """
    Limpia una cadena de texto realizando las siguientes operaciones:
    1. Convierte todo el texto a minúsculas.
    2. Elimina caracteres no imprimibles antes de la primera letra y después de la última letra,
       pero mantiene los caracteres internos.
    
    Parámetros:
    - cadena (str): La cadena de texto a limpiar.
    
    Retorna:
    - str: La cadena limpia.
    """
    if isinstance(cadena, str):
        # 1. Convertir todo a minúsculas
        cadena = cadena.lower()
        # 2. Eliminar caracteres no imprimibles antes de la primera letra y después de la última letra
        # Buscar la posición de la primera letra (a-z)
        primer_letra = re.search(r'[a-z]', cadena)
        # Buscar la posición de la última letra (a-z)
        ultima_letra = re.search(r'[a-z](?!.*[a-z])', cadena)
        
        if primer_letra and ultima_letra:
            inicio = primer_letra.start()
            fin = ultima_letra.end()
            cadena = cadena[inicio:fin]
        else:
            # Si no se encuentran letras, eliminar espacios en blanco
            cadena = cadena.strip()
        
        return cadena
    return cadena


# Aplicar la limpieza a las columnas categóricas
for col in categorical_cols:
    df[col] = df[col].apply(limpiar_cadena)
# Verificar los cambios
for col in categorical_cols:
    print(f"\nValores únicos después de limpieza en '{col}':")
    print(df[col].unique())
# Out:
# Valores únicos después de limpieza en 'gender':
# ['female' 'male']
#
# Valores únicos después de limpieza en 'partner':
# ['yes' 'no']
#
# Valores únicos después de limpieza en 'dependents':
# ['no' 'yes']
#
# Valores únicos después de limpieza en 'phoneservice':
# ['no' 'yes']
#
# Valores únicos después de limpieza en 'multiplelines':
# ['no phone service' 'no' 'yes']
#
# Valores únicos después de limpieza en 'internetservice':
# ['dsl' 'fiber optic' 'no']
#
# Valores únicos después de limpieza en 'onlinesecurity':
# ['no' 'yes' 'no internet service']
#
# Valores únicos después de limpieza en 'onlinebackup':
# ['yes' 'no' 'no internet service']
#
# Valores únicos después de limpieza en 'deviceprotection':
# ['no' 'yes' 'no internet service']
#
# Valores únicos después de limpieza en 'techsupport':
# ['no' 'yes' 'no internet service']
#
# Valores únicos después de limpieza en 'streamingtv':
# ['no' 'yes' 'no internet service']
#
# ...

# %%
# Guardar los valores únicos en un archivo JSON para referencia
valores_unicos = {}
for col in categorical_cols:
    unique_vals = df[col].dropna().unique().tolist()
    valores_unicos[col] = unique_vals
# Guardar en 'valores_unicos.json'
with open(r'C:\Users\GIGABYTE\Documents\examen_data_fundamentals\examen_intento_3\json\valores_unicos_finales.json', 'w', encoding='utf-8') as f:
    json.dump(valores_unicos, f, ensure_ascii=False, indent=4)
    print("Valores únicos guardados en 'valores_unicos_finales.json'.")
# Out:
# Valores únicos guardados en 'valores_unicos_finales.json'.

# %%
# Verificar Valores Nulos en todas las columnas
qsna=df.shape[0]-df.isnull().sum(axis=0)
qna=df.isnull().sum(axis=0)
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)
na.sort_values(by='Na en %',ascending=False)
# Out:
#                   datos sin NAs en q  Na en q  Na en %
# totalcharges                    7032       11     0.16
# gender                          7043        0     0.00
# seniorcitizen                   7043        0     0.00
# partner                         7043        0     0.00
# customerid                      7043        0     0.00
# dependents                      7043        0     0.00
# tenure                          7043        0     0.00
# multiplelines                   7043        0     0.00
# phoneservice                    7043        0     0.00
# onlinesecurity                  7043        0     0.00
# onlinebackup                    7043        0     0.00
# deviceprotection                7043        0     0.00
# internetservice                 7043        0     0.00
# techsupport                     7043        0     0.00
# streamingtv                     7043        0     0.00
# contract                        7043        0     0.00
# ...

# %%
df.describe()
# Out:
#             tenure  monthlycharges  totalcharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
# Calcular el promedio de la columna totalcharges ignorando los NaN
promedio_totalcharges = df['totalcharges'].astype(float).mean()

# Llenar los valores faltantes con el promedio calculado y asignar el resultado de nuevo a la columna
df['totalcharges'] = df['totalcharges'].fillna(promedio_totalcharges)

# Verificar que ya no existan valores faltantes en totalcharges
qsna=df.shape[0]-df.isnull().sum(axis=0)
qna=df.isnull().sum(axis=0)
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)
na.sort_values(by='Na en %',ascending=False)
# Out:
#                   datos sin NAs en q  Na en q  Na en %
# customerid                      7043        0      0.0
# gender                          7043        0      0.0
# seniorcitizen                   7043        0      0.0
# partner                         7043        0      0.0
# dependents                      7043        0      0.0
# tenure                          7043        0      0.0
# phoneservice                    7043        0      0.0
# multiplelines                   7043        0      0.0
# internetservice                 7043        0      0.0
# onlinesecurity                  7043        0      0.0
# onlinebackup                    7043        0      0.0
# deviceprotection                7043        0      0.0
# techsupport                     7043        0      0.0
# streamingtv                     7043        0      0.0
# streamingmovies                 7043        0      0.0
# contract                        7043        0      0.0
# ...

# %% [markdown]
# #### **Identificar y solucionar cualquier punto de dato inapropiado o inusual (ejemplo: la edad no puede ser 325).**

# %%
# Revisar y corregir valores para cada columna específica

# gender: validar valores únicos
df.loc[~df['gender'].isin(['female', 'male']), 'gender'] = np.nan

# partner: validar valores únicos
df.loc[~df['partner'].isin(['yes', 'no']), 'partner'] = np.nan

# dependents: validar valores únicos
df.loc[~df['dependents'].isin(['yes', 'no']), 'dependents'] = np.nan

# phoneservice: validar valores únicos
df.loc[~df['phoneservice'].isin(['yes', 'no']), 'phoneservice'] = np.nan

# multiplelines: validar valores únicos
df.loc[~df['multiplelines'].isin(['no phone service', 'no', 'yes']), 'multiplelines'] = np.nan

# internetservice: validar valores únicos
df.loc[~df['internetservice'].isin(['dsl', 'fiber optic', 'no']), 'internetservice'] = np.nan

# onlinesecurity: validar valores únicos
df.loc[~df['onlinesecurity'].isin(['yes', 'no', 'no internet service']), 'onlinesecurity'] = np.nan

# onlinebackup: validar valores únicos
df.loc[~df['onlinebackup'].isin(['yes', 'no', 'no internet service']), 'onlinebackup'] = np.nan

# deviceprotection: validar valores únicos
df.loc[~df['deviceprotection'].isin(['yes', 'no', 'no internet service']), 'deviceprotection'] = np.nan

# techsupport: validar valores únicos
df.loc[~df['techsupport'].isin(['yes', 'no', 'no internet service']), 'techsupport'] = np.nan

# streamingtv: validar valores únicos
df.loc[~df['streamingtv'].isin(['yes', 'no', 'no internet service']), 'streamingtv'] = np.nan

# streamingmovies: validar valores únicos
df.loc[~df['streamingmovies'].isin(['yes', 'no', 'no internet service']), 'streamingmovies'] = np.nan

# contract: validar valores únicos
df.loc[~df['contract'].isin(['month-to-month', 'one year', 'two year']), 'contract'] = np.nan

# paperlessbilling: validar valores únicos
df.loc[~df['paperlessbilling'].isin(['yes', 'no']), 'paperlessbilling'] = np.nan

# paymentmethod: filtrar valores fuera de los válidos
valid_payment_methods = ['electronic check', 'mailed check', 'bank transfer (automatic', 'credit card (automatic']
df.loc[~df['paymentmethod'].isin(valid_payment_methods), 'paymentmethod'] = np.nan

# Verificación final de datos corregidos
print("Revisión completa. Valores atípicos han sido ajustados o eliminados.")

# Resumen final del DataFrame
qsna=df.shape[0]-df.isnull().sum(axis=0)
qna=df.isnull().sum(axis=0)
ppna=round(100*(df.isnull().sum(axis=0)/df.shape[0]),2)
aux= {'datos sin NAs en q': qsna, 'Na en q': qna ,'Na en %': ppna}
na=pd.DataFrame(data=aux)
na.sort_values(by='Na en %',ascending=False)
# Out:
# Revisión completa. Valores atípicos han sido ajustados o eliminados.
#                   datos sin NAs en q  Na en q  Na en %
# customerid                      7043        0      0.0
# gender                          7043        0      0.0
# seniorcitizen                   7043        0      0.0
# partner                         7043        0      0.0
# dependents                      7043        0      0.0
# tenure                          7043        0      0.0
# phoneservice                    7043        0      0.0
# multiplelines                   7043        0      0.0
# internetservice                 7043        0      0.0
# onlinesecurity                  7043        0      0.0
# onlinebackup                    7043        0      0.0
# deviceprotection                7043        0      0.0
# techsupport                     7043        0      0.0
# streamingtv                     7043        0      0.0
# streamingmovies                 7043        0      0.0
# ...

# %% [markdown]
# ### 2.  Exploración de datos con Python:
#    * Crear dos tipos diferentes de visualizaciones exploratorias univariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.
#    * Crear dos tipos diferentes de visualizaciones exploratorias multivariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.

# %% [markdown]
# #### **Crear dos tipos diferentes de visualizaciones exploratorias univariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.**

# %%
# Configuración de estilo
sns.set(style='whitegrid')

# Visualización Univariada 1: Distribución de los cargos mensuales
plt.figure(figsize=(10, 6))
sns.histplot(df['monthlycharges'], bins=30, kde=True, color='blue')
plt.title('Distribución de los Cargos Mensuales')
plt.xlabel('Cargos Mensuales')
plt.ylabel('Frecuencia')
plt.axvline(df['monthlycharges'].mean(), color='red', linestyle='dashed', linewidth=1)
plt.text(df['monthlycharges'].mean(), 100, 'Media', color='red', ha='center')
plt.show()

'''
Interpretación:

* La distribución de los cargos mensuales muestra que la mayoría de los clientes tienen cargos 
relativamente bajos,con algunos pocos clientes con cargos significativamente más altos. La línea
roja representa la media,
que indica que la mayoría de los valores están por debajo de este promedio.

*  La distribución bimodal de los cargos mensuales sugiere una heterogeneidad en la base de clientes, 
lo que implica la necesidad de un enfoque más granular en las estrategias de marketing y retención.
'''
# Out:
# '\nInterpretación:\n\n* La distribución de los cargos mensuales muestra que la mayoría de los clientes tienen cargos \nrelativamente bajos,con algunos pocos clientes con cargos significativamente más altos. La línea\nroja representa la media,\nque indica que la mayoría de los valores están por debajo de este promedio.\n\n*  La distribución bimodal de los cargos mensuales sugiere una heterogeneidad en la base de clientes, \nlo que implica la necesidad de un enfoque más granular en las estrategias de marketing y retención.\n'

# %%
# Visualización Univariada 2: Distribución de Género
plt.figure(figsize=(8, 8))
df['gender'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral'])
plt.title('Distribución de Género de Clientes')
plt.ylabel('')
plt.show()

'''
Interpretación:
* El gráfico de barras muestra la distribución de género entre los clientes. 
Se puede observar que hay una ligera mayoría de clientes masculinos en comparación con los femeninos.

'''
# Out:
# '\nInterpretación:\n* El gráfico de barras muestra la distribución de género entre los clientes. \nSe puede observar que hay una ligera mayoría de clientes masculinos en comparación con los femeninos.\n\n'

# %%
# Gráfico de barras para visualizar la proporción de clientes que se han dado de baja
sns.countplot(data=df, x='churn')
plt.title('Proporción de Clientes que se Han Dado de Baja')
plt.show()

'''
Interpretación:
* La empresa tiene una base de clientes relativamente estable: La mayoría de los clientes 
continúan utilizando el servicio.
* Existe una tasa de churn significativa: A pesar de la estabilidad general, la empresa está 
perdiendo una cantidad considerable de clientes.
* Oportunidad de mejora: La alta tasa de churn representa una oportunidad para mejorar 
las estrategias de retención de clientes.
'''
# Out:
# '\nInterpretación:\n* La empresa tiene una base de clientes relativamente estable: La mayoría de los clientes \ncontinúan utilizando el servicio.\n* Existe una tasa de churn significativa: A pesar de la estabilidad general, la empresa está \nperdiendo una cantidad considerable de clientes.\n* Oportunidad de mejora: La alta tasa de churn representa una oportunidad para mejorar \nlas estrategias de retención de clientes.\n'

# %% [markdown]
# #### **Crear dos tipos diferentes de visualizaciones exploratorias multivariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.**

# %%
# Visualización Multivariada 1: Relación entre Cargos Mensuales y el Churn
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='churn', y='monthlycharges', palette='Set1')
plt.title('Relación entre Cargos Mensuales y Churn')
plt.xlabel('Churn')
plt.ylabel('Cargos Mensuales')
plt.show()


'''
# Interpretación:
Este boxplot muestra que los clientes que han cancelado (Churn = 'Yes') tienden a tener cargos mensuales más altos
en comparación con aquellos que no han cancelado (Churn = 'No'). 

* El precio influye en la decisión de los clientes: Clientes con cargos mensuales más altos tienen una mayor 
probabilidad de cancelar el servicio.
* Segmentación: Es posible que exista una segmentación de clientes basada en el nivel de gasto. Los clientes 
con cargos más altos podrían ser más sensibles al precio o estar buscando alternativas más económicas.
* Estrategias de retención: La empresa podría considerar ofrecer descuentos o promociones especiales a 
los clientes con cargos mensuales más altos para reducir la probabilidad de churn en este segmento.
'''
# Out:
# C:\Users\GIGABYTE\AppData\Local\Temp\ipykernel_5920\2560254301.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ...

# %%
# Visualización Multivariada 2: Muestra la proporción de clientes que churned según el tipo de contrato.
# Identificar si hay un tipo de contrato que tenga un mayor churn
plt.figure(figsize=(10, 6))
churn_contract = df.groupby('contract')['churn'].value_counts(normalize=True).unstack()
churn_contract.plot(kind='bar', stacked=True, color=['lightblue', 'lightcoral'])
plt.title('Proporción de Churn por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Proporción')
plt.legend(title='Churn')
plt.show()

'''
Interpretación:
* El tipo de contrato es un factor determinante en la retención de clientes. Los contratos a más largo 
plazo son más efectivos para reducir el churn.
* Los clientes con contratos de mes a mes requieren de estrategias de retención más agresivas. Se pueden 
ofrecer descuentos, beneficios adicionales o programas de lealtad para incentivar a estos clientes a renovar su contrato.
* La empresa podría considerar ofrecer incentivos para que los clientes migren a contratos de mayor 
duración. Esto no solo reduciría la tasa de churn, sino que también podría generar ingresos adicionales.
'''
# Out:
# '\nInterpretación:\n* El tipo de contrato es un factor determinante en la retención de clientes. Los contratos a más largo \nplazo son más efectivos para reducir el churn.\n* Los clientes con contratos de mes a mes requieren de estrategias de retención más agresivas. Se pueden \nofrecer descuentos, beneficios adicionales o programas de lealtad para incentivar a estos clientes a renovar su contrato.\n* La empresa podría considerar ofrecer incentivos para que los clientes migren a contratos de mayor \nduración. Esto no solo reduciría la tasa de churn, sino que también podría generar ingresos adicionales.\n'

# %% [markdown]
# #### **-----------------------------------------------------------------------------------**
